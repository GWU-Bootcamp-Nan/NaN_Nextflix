# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
 "Resources/Happiness_2017.csv"
netflix_df = pd.read_csv("Resources/netflix_titles.csv")
netflix_df
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
data=netflix_df[['show_id','type','title','director','country','release_year','rating','duration','listed_in']]
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director                                   country  \
# ...

# %%
movies= data[data['type']=='Movie']['type'].count()
movies
# Out:
# 4265

# %%
tv_show= data[data['type']=='TV Show']['type'].count()
tv_show
# Out:
# 1969

# %%
typ= {'type':['Movies','Tv Shows'],
       'count':[movies,tv_show]}
typ=pd.DataFrame(typ)

plt.pie(typ['count'], labels=typ['type'],explode = (0, 0.09), autopct="%.2f%%", shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x22991b39308>,
# ...
#  [Text(-0.9209948449724967, -0.6014719407703795, 'Movies'),
#   Text(0.9963490295734261, 0.6506831880939388, 'Tv Shows')],
#  [Text(-0.5023608245304527, -0.32807560405657055, '68.42%'),
#   Text(0.5777149835341713, 0.3772868905754771, '31.58%')])

# %%
movies_df= data[data['type']=='Movie']
movies_df
# Out:
#        show_id   type                                    title  \
# 0     81145628  Movie  Norm of the North: King Sized Adventure
# 1     80117401  Movie               Jandino: Whatever it Takes
# 4     80125979  Movie                             #realityhigh
# 6     70304989  Movie                                 Automata
# 7     80164077  Movie       Fabrizio Copano: Solo pienso en mi
# ...        ...    ...                                      ...
# 5577  80085438  Movie                          Frank and Cindy
# 5578  80085439  Movie                          Frank and Cindy
# 5579  80011846  Movie                                  Iverson
# 5580  80064521  Movie      Jeremy Scott: The People's Designer
# 6231  80116008  Movie   Little Baby Bum: Nursery Rhyme Friends
#
#                              director  \
# 0            Richard Finn, Tim Maltby
# 1                                 NaN
# 4                    Fernando Lebrija
# 6                         Gabe Ibáñez
# ...

# %%
countries=movies_df['country'].value_counts()

# %%
countries.head(20).plot(kind="barh")
plt.show()

# %%
tv_show_df= data[data['type']=='TV Show']
tv_show_df
# Out:
#        show_id     type                                        title director  \
# 2     70234439  TV Show                           Transformers Prime      NaN
# 3     80058654  TV Show             Transformers: Robots in Disguise      NaN
# 5     80163890  TV Show                                      Apaches      NaN
# 8     80117902  TV Show                                 Fire Chasers      NaN
# 26    80244601  TV Show                              Castle of Stars      NaN
# ...        ...      ...                                          ...      ...
# 6228  80159925  TV Show                                     Kikoriki      NaN
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
# ...

# %%
countriess=tv_show_df['country'].value_counts()

# %%
countriess.head(20).plot(kind="barh")
plt.show()

# %%
countriest=data['country'].value_counts()


countriest.head(20).plot(kind="barh")
plt.show()
